# %% [markdown]
# # Session 0 - Getting Started with Google Colab, Jupyter, and Python

# %% [markdown]
# ![Getting Started with Google Colab, Jupyter, and Python](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/getting_started_with_google_colab_jypyter_python_lnb.png)

# %% [markdown]
# This notebook is for participants who have never used Jupyter notebooks, Google Colab, or Python before.
#
# Please work through it a day or a few days before the workshop. You do not need to install anything if you use Google Colab.
#
# By the end, you should be comfortable enough to open Session 1 and focus on the LLM/API ideas instead of the mechanics of running code.

# %% [markdown]
# ## Estimated completion time
#
# How long this notebook takes depends on your previous experience:
#
# - **Beginner:** about **60–90 minutes** if Python and notebooks are new to you. Take your time, run every code cell, and try the exercises.
# - **Intermediate user:** about **20–30 minutes** to review the explanations and complete the exercises.
# - **Advanced user:** about **0–10 minutes**. You can skim the notebook or skip it if you already feel comfortable with Python and Jupyter notebooks.
#
# These are only estimates. It is fine to pause, experiment, or return to the notebook later.

# %% [markdown]
# ## What you will practice
#
# - Reading formatted text cells in a notebook.
# - Running Python code cells.
# - Understanding Google Colab as a cloud version of Jupyter notebooks.
# - Writing simple Markdown.
# - Using variables to keep data during a notebook session.
# - Using basic Python: values, operations, strings, lists, dictionaries, conditions, loops, and functions.
#
# There are no API keys, paid services, or advanced programming topics in this notebook.

# %% [markdown]
# ## 0. What is Python?
#
# Python is a **programming language**: a way to write instructions that a computer can follow. You write those instructions as text called **code**, and Python reads the code and carries out the steps.
#
# Python is popular with beginners because its code is designed to be relatively easy to read. It is also widely used by researchers for working with text and data, automating repetitive tasks, creating visualizations, and communicating with online services such as APIs.
#
# For example, this Python instruction asks the computer to display a message: `print("Hello")`. You do not need to memorize it now. In this notebook, you will learn by running small examples, changing them, and seeing what happens. Making mistakes is a normal and useful part of learning to code.

# %% [markdown]
# ## 1. The core idea of a Jupyter notebook

# %% [markdown]
# ![Jupyter Notebook Idea](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/jupyter_notebook_idea.png)

# %% [markdown]
# A Jupyter notebook combines two things in one document:
#
# 1. **Formatted text cells**, like this one.
# 2. **Code cells**, which can run Python code.
#
# This is why notebooks are useful for research and teaching. You can keep explanation, code, results, and notes together in one place.

# %% [markdown]
# ### This is a formatted text cell
#
# It can contain paragraphs, **bold text**, bullet lists, links, and small pieces of code such as `print("Hello")`.
#
# You read this cell. You do not run it as Python code.

# %%
# This is a code cell.
# Click inside it and press Shift+Enter to run it.

print("Hello from Python")

# %% [markdown]
# ### Try it
#
# Run the code cell below. Then change the sentence and run it again.

# %%
print("I can run code in a notebook.")

# %% [markdown]
# ## 2. Google Colab as cloud Jupyter

# %% [markdown]
# ![Google Colab Cloud Runtime](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/google_colab_cloud_runtime.png)

# %% [markdown]
# Google Colab is a version of Jupyter notebooks that runs in a web browser.
#
# The important idea is that the code usually runs on a temporary cloud computer provided by Google, not directly on your laptop.
#
# That means:
#
# - You can use Python without installing Python first.
# - The notebook can be opened from GitHub or Google Drive.
# - The active runtime session keeps your variables in memory.
# - If the runtime disconnects or restarts, variables and temporary files disappear.
# - You can rerun notebook cells to rebuild the session state.

# %% [markdown]
# ### Runtime session: a simple example
#
# Run the next cell. It creates a variable named `session_note`. Then run the cell after it, which uses that same variable.

# %%
session_note = "This text is stored in memory during the current runtime session."

# %%
print(session_note)

# %% [markdown]
# If you restart the runtime and run only the second cell, Python will not know what `session_note` means. In notebooks, order matters.

# %% [markdown]
# ## 3. Short Markdown refresher

# %% [markdown]
# ![Markdown](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/markdown.png)

# %% [markdown]
# Markdown is a simple way to write formatted text.
#
# Here are common patterns:
#
# ```markdown
# # Large heading
# ## Medium heading
# ### Small heading
#
# **bold text**
# *italic text*
#
# - Bullet item
# - Another bullet item
#
# 1. First numbered item
# 2. Second numbered item
#
# [Link text](https://example.com)
#
# `short code example`
# ```
#
# Markdown cells are useful for research notes, source descriptions, explanations, and reminders to yourself.

# %% [markdown]
# ### Markdown exercise
#
# Insert a new text cell below this one, or edit this cell if you are practicing in your own copy.
#
# Write a short research note that includes:
#
# - one heading,
# - one bold phrase,
# - one bullet list,
# - one link or one inline code example.

# %% [markdown]
# ## 4. Variables hold data during the session

# %% [markdown]
# ![Variables](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/variables.png)

# %% [markdown]
# A variable is a name that points to a value.
#
# In a notebook, variables are available after you run the cell that creates them. They stay available while the runtime session is active.

# %%
researcher_name = "Anna"
document_count = 12
language = "English"

print(researcher_name)
print(document_count)
print(language)

# %% [markdown]
# You can use variables later in another cell.

# %%
summary = researcher_name + " is working with " + str(document_count) + " documents."
print(summary)

# %% [markdown]
# You can also update a variable by assigning a new value to it.

# %%
document_count = document_count + 1
print(document_count)

# %% [markdown]
# ### Variable exercise
#
# Run the next cell. Then change the values to describe a project of your own.

# %%
project_title = "Newspaper language study"
project_year = 1936
number_of_sources = 5
source_language = "Latvian"

print("Project:", project_title)
print("Year:", project_year)
print("Sources:", number_of_sources)
print("Language:", source_language)

# %% [markdown]
# ## 5. Python basics: values and types

# %% [markdown]
# ![Values, Types, and Operations](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/values_types_operations.png)

# %% [markdown]
# Python values have types. The type tells Python what kind of data it is working with.
#
# Common beginner types:
#
# - `str`: text, also called a string.
# - `int`: whole number.
# - `float`: decimal number.
# - `bool`: true or false value.

# %%
title = "Latvian Economic Review"
year = 1938
average_pages = 14.5
is_digitized = True

print(type(title))
print(type(year))
print(type(average_pages))
print(type(is_digitized))

# %% [markdown]
# ### Type exercise
#
# Before you run the next cell, guess the type of each value.

# %%
value_a = "1918"
value_b = 1918
value_c = 19.18
value_d = False

print(value_a, type(value_a))
print(value_b, type(value_b))
print(value_c, type(value_c))
print(value_d, type(value_d))

# %% [markdown]
# ## 6. Basic operations
#
# Python can do arithmetic with numbers.
#
# - `+` addition
# - `-` subtraction
# - `*` multiplication
# - `/` division
# - `//` whole-number division
# - `%` remainder
# - `**` power

# %%
pages = 120
issues = 8

print("Pages per issue:", pages / issues)
print("Whole pages per issue:", pages // issues)
print("Remainder:", pages % issues)

# %% [markdown]
# Strings use some of the same symbols, but the meaning is different. With strings, `+` joins text together.

# %%
first_word = "Digital"
second_word = "Humanities"

phrase = first_word + " " + second_word
print(phrase)

# %% [markdown]
# ### Operations exercise
#
# Change the values below and rerun the cell.

# %%
total_words = 2400
page_count = 12

words_per_page = total_words / page_count
print("Words per page:", words_per_page)

# %% [markdown]
# ## 7. Working with text

# %% [markdown]
# ![Text](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/text.png)

# %% [markdown]
# Text values are strings. Humanities data often starts as text, so string operations are very useful.

# %%
sample_text = "The archive contains newspapers, letters, and reports."

print("Characters:", len(sample_text))
print("Lowercase:", sample_text.lower())
print("Uppercase:", sample_text.upper())
print("Contains archive?", "archive" in sample_text)
print("Updated text:", sample_text.replace("reports", "catalogues"))

# %% [markdown]
# Splitting text into words is one simple way to begin analyzing it.

# %%
words = sample_text.split()

print(words)
print("Word count:", len(words))

# %% [markdown]
# ### Text exercise
#
# Change `short_source_text` to a sentence from your own research area.

# %%
short_source_text = "A census record can contain names, places, ages, and occupations."

word_list = short_source_text.split()
print("Text:", short_source_text)
print("Words:", word_list)
print("Word count:", len(word_list))

# %% [markdown]
# ## 8. Lists

# %% [markdown]
# ![List Data Type](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/list_data_type.png)

# %% [markdown]
# A list stores several values in order.
#
# Lists are useful when you have several texts, titles, years, names, or results.

# %%
source_titles = ["Issue 1", "Issue 2", "Issue 3"]

print(source_titles)
print("Number of titles:", len(source_titles))
print("First title:", source_titles[0])
print("Last title:", source_titles[-1])

# %%
source_titles.append("Issue 4")
print(source_titles)

# %% [markdown]
# ### List exercise
#
# Make a list of five sources, authors, topics, or languages.

# %%
my_sources = ["newspaper", "letter", "diary", "report", "map"]

print("All sources:", my_sources)
print("First source:", my_sources[0])
print("Last source:", my_sources[-1])

# %% [markdown]
# ## 9. Dictionaries

# %% [markdown]
# ![Dictionary](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/dictionary.png)

# %% [markdown]
# A dictionary stores named pieces of information.
#
# This is useful for metadata, where each value has a label such as title, year, language, or place.

# %%
document = {
    "title": "Example report",
    "year": 1936,
    "language": "English",
    "pages": 12
}

print(document)
print(document["title"])
print(document["year"])

# %% [markdown]
# You can add or update values in a dictionary.

# %%
document["pages"] = 14
document["collection"] = "Workshop sample collection"

print(document)

# %% [markdown]
# ### Dictionary exercise
#
# Change the values below to describe one source from your own field.

# %%
my_document = {
    "title": "Sample source",
    "year": 1900,
    "language": "German",
    "source_type": "newspaper"
}

print("Title:", my_document["title"])
print("Year:", my_document["year"])
print("Language:", my_document["language"])
print("Type:", my_document["source_type"])

# %% [markdown]
# ## 10. Comparisons and conditions

# %% [markdown]
# ![Conditions](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/conditions.png)

# %% [markdown]
# Comparisons ask questions that produce `True` or `False`.
#
# Common comparison operators:
#
# - `==` equal to
# - `!=` not equal to
# - `<` less than
# - `>` greater than
# - `<=` less than or equal to
# - `>=` greater than or equal to

# %%
year = 1918

print(year == 1918)
print(year < 1900)
print(year >= 1900)

# %% [markdown]
# An `if` statement lets Python choose what to do based on a condition.

# %%
year = 1918

if year < 1900:
    period = "19th century or earlier"
else:
    period = "20th century or later"

print(period)

# %% [markdown]
# ### Condition exercise
#
# Change `word_count` and rerun the cell.

# %%
word_count = 850

if word_count < 500:
    length_label = "short"
elif word_count < 1500:
    length_label = "medium"
else:
    length_label = "long"

print("This document is", length_label)

# %% [markdown]
# ## 11. Loops

# %% [markdown]
# ![Loops](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/loops.png)

# %% [markdown]
# A loop repeats the same action for each item in a sequence.
#
# `for` loops are especially useful when working with lists of documents.

# %%
titles = ["Issue 1", "Issue 2", "Issue 3"]

for title in titles:
    print("Processing", title)

# %% [markdown]
# Loops can also combine several steps.

# %%
texts = [
    "Short note about an archive.",
    "A longer sentence about newspapers and reports.",
    "One more sample text."
]

for text in texts:
    words = text.split()
    print(len(words), "words:", text)

# %% [markdown]
# ### Loop exercise
#
# Add one more title to the list and rerun the cell.

# %%
my_titles = ["Letter A", "Letter B", "Letter C"]

for number, title in enumerate(my_titles, start=1):
    print(number, title)

# %% [markdown]
# ## 12. Functions

# %% [markdown]
# ![Functions](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/functions.png)

# %% [markdown]
# A function is a reusable block of code.
#
# Functions are useful when you want to perform the same operation many times, such as counting words in many texts.

# %%
def count_words(text):
    words = text.split()
    return len(words)

print(count_words("This is a short text."))
print(count_words("This is another example with more words."))

# %% [markdown]
# A function can call another function or use conditions inside it.

# %%
def label_text_length(text):
    word_count = count_words(text)

    if word_count < 5:
        return "very short"
    elif word_count < 12:
        return "short"
    else:
        return "long"

print(label_text_length("Small note."))
print(label_text_length("This paragraph contains enough words to get a different label."))

# %% [markdown]
# ### Function exercise
#
# Complete the idea below by changing the thresholds or labels.

# %%
def label_document_by_year(year):
    if year < 1800:
        return "early source"
    elif year < 1950:
        return "modern historical source"
    else:
        return "recent source"

print(label_document_by_year(1750))
print(label_document_by_year(1918))
print(label_document_by_year(2020))

# %% [markdown]
# ## 13. Built-in functions and imports
#
# Python includes many built-in functions. You have already used several:
#
# - `print()` displays output.
# - `len()` counts items or characters.
# - `type()` shows the type of a value.
# - `str()` converts a value to text.
# - `sum()`, `min()`, and `max()` work with lists of numbers.
#
# Python can also import extra tools from modules.

# %%
word_counts = [120, 450, 310, 90]

print("Total words:", sum(word_counts))
print("Smallest document:", min(word_counts))
print("Largest document:", max(word_counts))
print("Average:", sum(word_counts) / len(word_counts))

# %%
from datetime import date

today = date.today()
print("Today is", today)

# %% [markdown]
# ## 14. Mini practice: a small humanities data workflow

# %% [markdown]
# ![Mini Humanities Workflow](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/mini_humanities_workflow.png)

# %% [markdown]
# The next cells combine the beginner ideas from this notebook.
#
# We will:
#
# 1. Store several source texts.
# 2. Count words in each text.
# 3. Label each text by length.
# 4. Store the results in dictionaries.
# 5. Print a simple summary.

# %%
source_texts = [
    "The archive contains letters from several families.",
    "This newspaper issue reports on trade, agriculture, and local politics.",
    "A short catalogue note."
]

print("Number of source texts:", len(source_texts))

# %%
def simple_length_label(word_count):
    if word_count < 5:
        return "very short"
    elif word_count < 10:
        return "short"
    else:
        return "long"


analysis_results = []

for text in source_texts:
    word_count = count_words(text)
    result = {
        "text": text,
        "word_count": word_count,
        "length_label": simple_length_label(word_count)
    }
    analysis_results.append(result)

print(analysis_results)

# %%
for result in analysis_results:
    print(result["word_count"], "words", "-", result["length_label"], "-", result["text"])

# %% [markdown]
# ### Mini practice exercise
#
# Add one more text to `source_texts`, then rerun the three mini practice code cells.
#
# Notice how the result changes when the input data changes.

# %% [markdown]
# ## 15. What this notebook does not cover
#
# This is only a beginner preparation notebook.
#
# It does not cover:
#
# - classes and object-oriented programming,
# - advanced error handling,
# - package installation,
# - pandas dataframes,
# - APIs,
# - JSON in detail,
# - LLM prompts or model responses.
#
# Those topics are either unnecessary for the first step or will be introduced later only when needed.

# %% [markdown]
# ## 16. Ready for Session 1 checklist

# %% [markdown]
# ![Ready for Session 1 Checklist](https://raw.githubusercontent.com/LNB-DH/BSSDH_2026_LLM_API_workshop/main/img/session_0/ready_for_session_1_checklist.png)

# %% [markdown]
# You are ready to continue when these statements feel familiar:
#
# - I can tell the difference between a text cell and a code cell.
# - I can run a code cell in Google Colab.
# - I understand that Colab runs code in a temporary cloud session.
# - I know that variables keep data during the active runtime session.
# - I can make and use strings, numbers, lists, and dictionaries.
# - I can read simple `if`, `for`, and `def` examples.
# - I understand that notebooks can combine explanation, code, and results.
#
# Now continue with `workshop_session_1.ipynb`.
